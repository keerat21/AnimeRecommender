# %%
import numpy as np
import pandas as pd

# %%
anime = pd.read_csv(r'C:\Users\Keats\OneDrive\Desktop\AnimeRecommender\anime.csv')
rating = pd.read_csv(r'C:\Users\Keats\OneDrive\Desktop\AnimeRecommender\rating.csv')

# %%
anime
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
rating
# Out:
#          user_id  anime_id  rating
# 0              1        20      -1
# 1              1        24      -1
# 2              1        79      -1
# 3              1       226      -1
# 4              1       241      -1
# ...          ...       ...     ...
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9
#
# [7813737 rows x 3 columns]

# %%
anirate = pd.merge(rating,anime,on='anime_id')

# %%
anirate
# Out:
#          user_id  anime_id  rating_x  \
# 0              1        20        -1
# 1              3        20         8
# 2              5        20         6
# 3              6        20        -1
# 4             10        20        -1
# ...          ...       ...       ...
# 7813722    65682     30450         8
# 7813723    69497     33484        10
# 7813724    70463     29481        -1
# 7813725    72404     34412        -1
# 7813726    72800     30738         4
#
#                                                       name  \
# 0                                                   Naruto
# 1                                                   Naruto
# 2                                                   Naruto
# 3                                                   Naruto
# 4                                                   Naruto
# ...                                                    ...
# 7813722  Dr. Slump: Hoyoyo! Arale no Himitsu Dai Koukai...
# ...

# %%
rating.groupby('anime_id')['rating'].mean()
# Out:
# anime_id
# 1        7.558514
# 5        6.890284
# 6        6.980590
# 7        6.040320
# 8        5.113801
#            ...
# 34367    4.000000
# 34412   -1.000000
# 34475    4.750000
# 34476   -1.000000
# 34519   -1.000000
# Name: rating, Length: 11200, dtype: float64

# %%
anime
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
wrating = rating[rating['rating'] != -1]

# %%
k1=rating.groupby('anime_id')['rating'].mean()

# %%
k2=rating.groupby('anime_id')['user_id'].count()

# %%
anirate = pd.merge(k1,k2,on='anime_id')

# %%
anirate['count'] = anirate['user_id']

# %%
anirate.drop(columns='user_id',inplace=True)

# %%
anirate['anime_id'] = anirate.index

# %%
anirate.set_index(np.arange(1,11201),inplace=True)

# %%
anirate = pd.merge(anirate,anime[['rating','members','anime_id']], on='anime_id')

# %%
anirate.rename(columns={'rating_x':'rating_count','rating_y':'rating_anime'},inplace=True)

# %%
anirate
# Out:
#        rating_count  count  anime_id  rating_anime  members
# 0          7.558514  15509         1          8.82   486824
# 1          6.890284   6927         5          8.40   137636
# 2          6.980590  11077         6          8.32   283069
# 3          6.040320   2629         7          7.36    64905
# 4          5.113801    413         8          7.06     9848
# ...             ...    ...       ...           ...      ...
# 11192      4.000000      5     34367          5.97      582
# 11193     -1.000000      1     34412          6.76      239
# 11194      4.750000      4     34475          6.58      313
# 11195     -1.000000      1     34476          1.67       51
# 11196     -1.000000      1     34519          5.67       94
#
# [11197 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.scatterplot(anirate['rating_anime'],anirate['members'],s=20,hue=anime['type'])

# %%
anirate[anirate['rating_anime'] == 1.67]
# Out:
#        rating_count  count  anime_id  rating_anime  members
# 11195          -1.0      1     34476          1.67       51

# %%
wrating[wrating['anime_id'] == 20]['rating']
# Out:
# 156         8
# 306         6
# 2282        8
# 2795        9
# 3114        9
#            ..
# 7811138     7
# 7811298    10
# 7811299     8
# 7811363     8
# 7811963     8
# Name: rating, Length: 22071, dtype: int64

# %%
anirate
# Out:
#        rating_count  count  anime_id  rating_anime  members
# 0          7.558514  15509         1          8.82   486824
# 1          6.890284   6927         5          8.40   137636
# 2          6.980590  11077         6          8.32   283069
# 3          6.040320   2629         7          7.36    64905
# 4          5.113801    413         8          7.06     9848
# ...             ...    ...       ...           ...      ...
# 11192      4.000000      5     34367          5.97      582
# 11193     -1.000000      1     34412          6.76      239
# 11194      4.750000      4     34475          6.58      313
# 11195     -1.000000      1     34476          1.67       51
# 11196     -1.000000      1     34519          5.67       94
#
# [11197 rows x 5 columns]

# %%
df = rating.pivot_table(index='user_id',columns='anime_id',values='rating')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-25-9759a95fcda3> in <module>
# ----> 1 df = rating.pivot_table(index='user_id',columns='anime_id',values='rating')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6078             dropna=dropna,
#    6079             margins_name=margins_name,
# -> 6080             observed=observed,
#    6081         )
#    6082
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#     146
#     147     if isinstance(table, ABCDataFrame):
# --> 148         table = table.sort_index(axis=1)
#     149
#     150     if fill_value is not None:
#
# ...

# %%
df

# %%
anirate.sort_values('count',ascending=False).head(10)
# Out:
#       rating_count  count  anime_id  rating_anime  members
# 1389      7.556177  39340      1535          8.71  1013917
# 6606      6.863159  30583     11757          7.83   893100
# 7439      7.314089  29584     16498          8.54   896229
# 1427      7.641244  27718      1575          8.83   715151
# 201       6.753508  27506       226          7.85   623511
# 4630      7.278667  27183      6547          8.39   717796
# 10        6.571726  25925        20          7.81   683297
# 99        7.056048  25032       121          8.33   600384
# 3965      8.028933  24574      5114          9.26   793665
# 3558      7.234938  24283      4224          8.45   633817

# %%
anime[anime['anime_id'] == 1535]
# Out:
#     anime_id        name                                              genre  \
# 40      1535  Death Note  Mystery, Police, Psychological, Supernatural, ...
#
#    type episodes  rating  members
# 40   TV       37    8.71  1013917

# %%
anirate[anirate['anime_id'] == 7980]
# Out:
#       rating_count  count  anime_id  rating_anime  members
# 5194           4.0      3      7980          5.78      124

# %%
dn_data = df[1535]

# %%
dn_data
# Out:
# user_id
# 1         NaN
# 2         NaN
# 3        10.0
# 4        -1.0
# 5         4.0
#          ...
# 73512     NaN
# 73513     NaN
# 73514     NaN
# 73515    10.0
# 73516     NaN
# Name: 1535, Length: 73515, dtype: float64

# %%
corr_dn = df.corrwith(dn_data.dropna())
# Out:
# C:\Users\Keats\anaconda3\lib\site-packages\numpy\lib\function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\Keats\anaconda3\lib\site-packages\numpy\lib\function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
df.loc[:,1535]

# %%
df.loc[3,34367]

# %%
corr_dn = pd.DataFrame(corr_dn,columns=['correlation'])

# %%
corr_dn

# %%
corr_dn.drop(columns=['count','anime_id'],inplace=True)

# %%
corr_dn = corr_dn.merge(anirate[['count','anime_id']], on='anime_id')

# %%
corr_dn[corr_dn['count']>50].sort_values(by='correlation',ascending=False)

# %%
anime[anime['anime_id'] == 7980]

# %%
anirate['rating_count'].hist(bins = 10, edgecolor='black')

# %%
corr_dn[corr_dn['count']>500].dropna().sort_values(by='correlation',ascending=False)
